# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col = 0)
pd.set_option('display.max_columns', None)

# %% [markdown]
# extracing data and cleaning

# %%
matches.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'xG', 'xGA', 'Poss', 'Attendance', 'Captain', 'Formation',
#        'Referee', 'Match Report', 'Notes', 'Sh', 'SoT', 'Dist', 'FK', 'PK',
#        'PKatt', 'Season', 'Team'],
#       dtype='object')

# %%
matches.columns = matches.columns.str.lower()

# %%
matches.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team'],
#       dtype='object')

# %%
matches.shape
# Out:
# (760, 27)

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2023-08-11  20:00  Premier League  Matchweek 1  Fri  Away      W   3   0
# 3  2023-08-19  20:00  Premier League  Matchweek 2  Sat  Home      W   1   0
# 4  2023-08-27  14:00  Premier League  Matchweek 3  Sun  Away      W   2   1
# 5  2023-09-02  15:00  Premier League  Matchweek 4  Sat  Home      W   5   1
# 6  2023-09-16  15:00  Premier League  Matchweek 5  Sat  Away      W   3   1
#
#         opponent   xg  xga  poss  attendance          captain formation  \
# 1        Burnley  1.9  0.3  65.0     21572.0  Kevin De Bruyne   4-2-3-1
# 3  Newcastle Utd  1.0  0.3  59.0     53419.0      Kyle Walker   4-2-3-1
# 4  Sheffield Utd  3.5  0.7  79.0     31336.0      Kyle Walker   4-2-3-1
# 5         Fulham  2.2  1.4  68.0     52899.0      Kyle Walker   4-2-3-1
# 6       West Ham  3.6  0.9  68.0     62475.0      Kyle Walker   4-2-3-1
#
#           referee  match report  notes    sh   sot  dist   fk  pk  pkatt  \
# 1    Craig Pawson  Match Report    NaN  17.0   8.0  13.9  0.0   0      0
# 3    Robert Jones  Match Report    NaN  14.0   4.0  17.9  0.0   0      0
# 4  Jarred Gillett  Match Report    NaN  29.0   9.0  17.3  2.0   0      1
# 5  Michael Oliver  Match Report    NaN   6.0   4.0  14.8  0.0   1      1
# 6     Andy Madley  Match Report    NaN  29.0  13.0  16.4  1.0   0      0
#
#    season            team
# 1    2024  ManchesterCity
# 3    2024  ManchesterCity
# 4    2024  ManchesterCity
# 5    2024  ManchesterCity
# 6    2024  ManchesterCity

# %%
cat_cols = ['day', 'venue', 'result', 'opponent', 'captain', 'formation', 'referee', 'team']

num_cols = ['date', 'time', 'round', 'gf', 'ga', 'xg', 'xga', 'poss', 'attendance', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt', 'season']

drop_cols = ['comp', 'match report', 'notes']

# %%
matches = matches.drop(columns=drop_cols)

# %%
matches.shape
# Out:
# (760, 24)

# %% [markdown]
# transforming categorical columns into numerical formating to prepare for machine learning

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches["day_code"] = matches["date"].dt.day_of_week
matches["target"] = (matches["result"] == "W").astype("int")

# %% [markdown]
# I have encoded a win as 1 and losses/draws as 0

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50,
                            min_samples_split=10,
                            random_state=1
                            )

# %%
matches.head(5)
# Out:
#         date   time        round  day venue result  gf  ga       opponent  \
# 1 2023-08-11  20:00  Matchweek 1  Fri  Away      W   3   0        Burnley
# 3 2023-08-19  20:00  Matchweek 2  Sat  Home      W   1   0  Newcastle Utd
# 4 2023-08-27  14:00  Matchweek 3  Sun  Away      W   2   1  Sheffield Utd
# 5 2023-09-02  15:00  Matchweek 4  Sat  Home      W   5   1         Fulham
# 6 2023-09-16  15:00  Matchweek 5  Sat  Away      W   3   1       West Ham
#
#     xg  xga  poss  attendance          captain formation         referee  \
# 1  1.9  0.3  65.0     21572.0  Kevin De Bruyne   4-2-3-1    Craig Pawson
# 3  1.0  0.3  59.0     53419.0      Kyle Walker   4-2-3-1    Robert Jones
# 4  3.5  0.7  79.0     31336.0      Kyle Walker   4-2-3-1  Jarred Gillett
# 5  2.2  1.4  68.0     52899.0      Kyle Walker   4-2-3-1  Michael Oliver
# 6  3.6  0.9  68.0     62475.0      Kyle Walker   4-2-3-1     Andy Madley
#
#      sh   sot  dist   fk  pk  pkatt  season            team  venue_code  \
# 1  17.0   8.0  13.9  0.0   0      0    2024  ManchesterCity           0
# 3  14.0   4.0  17.9  0.0   0      0    2024  ManchesterCity           1
# 4  29.0   9.0  17.3  2.0   0      1    2024  ManchesterCity           0
# 5   6.0   4.0  14.8  0.0   1      1    2024  ManchesterCity           1
# 6  29.0  13.0  16.4  1.0   0      0    2024  ManchesterCity           0
#
#    opp_code  hour  day_code  target
# 1         5    20         4       1
# 3        14    20         5       1
# 4        16    14         6       1
# 5         9    15         5       1
# 6        18    15         5       1

# %%
matches.sort_values(by='date').iloc[len(matches)//2:]
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 20 2023-12-30  15:00  Matchweek 20  Sat  Away      L   0   2  Manchester City
# 23 2023-12-30  15:00  Matchweek 20  Sat  Away      L   0   3           Wolves
# 20 2023-12-30  17:30  Matchweek 20  Sat  Home      W   2   1   Manchester Utd
# 27 2023-12-30  17:30  Matchweek 20  Sat  Away      L   1   2  Nott'ham Forest
# 21 2023-12-30  15:00  Matchweek 20  Sat  Home      W   3   1        Brentford
# ..        ...    ...           ...  ...   ...    ...  ..  ..              ...
# 44 2024-05-19  16:00  Matchweek 38  Sun  Away      L   1   2          Arsenal
# 41 2024-05-19  16:00  Matchweek 38  Sun  Home      L   2   4    Newcastle Utd
# 43 2024-05-19  16:00  Matchweek 38  Sun  Away      W   2   1          Burnley
# 52 2024-05-19  16:00  Matchweek 38  Sun  Away      L   1   3  Manchester City
# 40 2024-05-19  16:00  Matchweek 38  Sun  Home      L   0   3        Tottenham
#
#      xg  xga  poss  attendance             captain formation         referee  \
# 20  0.3  2.2  20.0     53108.0       Jack Robinson     3-4-3     David Coote
# 23  0.4  1.9  47.0     31639.0     James Tarkowski     5-4-1  Thomas Bramall
# 20  0.7  0.8  44.0     29529.0          Ryan Yates   4-2-3-1    Tim Robinson
# 27  0.8  0.7  56.0     29529.0     Bruno Fernandes   4-2-3-1    Tim Robinson
# 21  1.0  1.4  46.0     25472.0          Marc Guéhi     4-3-3    Robert Jones
# ..  ...  ...   ...         ...                 ...       ...             ...
# 44  0.6  2.9  32.0     60312.0      Séamus Coleman   4-4-1-1  Michael Oliver
# 41  1.1  3.4  54.0     17124.0  Christian Nørgaard     4-3-3    Simon Hooper
# 43  1.7  1.2  28.0     21109.0          Ryan Yates   4-2-3-1    Graham Scott
# 52  0.4  1.9  29.0     55097.0          Kurt Zouma     3-4-3     John Brooks
# 40  1.0  3.1  25.0     29116.0       Jack Robinson     5-3-2     Andy Madley
#
#       sh  sot  dist   fk  pk  pkatt  season              team  venue_code  \
# 20   4.0  2.0  14.9  0.0   0      0    2024   SheffieldUnited           0
# 23  10.0  0.0  20.7  0.0   0      0    2024           Everton           0
# 20   8.0  2.0  18.3  0.0   0      0    2024  NottinghamForest           1
# 27  10.0  5.0  17.5  0.0   0      0    2024  ManchesterUnited           0
# 21  13.0  6.0  16.2  0.0   0      0    2024     CrystalPalace           1
# ..   ...  ...   ...  ...  ..    ...     ...               ...         ...
# 44   5.0  2.0  20.3  2.0   0      0    2024           Everton           0
# 41  10.0  5.0  15.9  1.0   0      0    2024         Brentford           1
# 43  12.0  6.0  17.2  0.0   0      0    2024  NottinghamForest           0
# 52   3.0  2.0  10.3  0.0   0      0    2024     WestHamUnited           0
# 40   6.0  1.0  18.0  1.0   0      0    2024   SheffieldUnited           1
#
#     opp_code  hour  day_code  target
# 20        12    15         5       0
# 23        19    15         5       0
# 20        13    17         5       1
# 27        15    17         5       0
# 21         3    15         5       1
# ..       ...   ...       ...     ...
# 44         0    16         6       0
# 41        14    16         6       0
# 43         5    16         6       1
# 52        12    16         6       0
# 40        17    16         6       0
#
# [380 rows x 29 columns]

# %%
train = matches[matches["date"] <= "2023-12-30"]
test = matches[matches["date"] > "2023-12-30"]

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6075268817204301

# %%
combined = pd.DataFrame(dict(actual=test["target"], predictions=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predictions"])
# Out:
# predictions    0   1
# actual
# 0            166  66
# 1             80  60

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.47619047619047616

# %% [markdown]
# 47.6% precision is quite low. I will now improve my feature selection.

# %%
grouped_matches = matches.groupby("team")
group = grouped_matches.get_group("ManchesterCity")
group.shape
# Out:
# (38, 29)

# %% [markdown]
# Implementing rolling_averages to use as input data for machine learning to improve model

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(5, closed="left").mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %% [markdown]
# identifying which columns to calculate rolling averages for

# %%
cols = ['gf', 'ga', 'xg', 'xga', 'poss', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt']
new_cols = [f"{c}_rolling" for c in cols]

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result  gf  ga         opponent  \
# 8  2023-09-23  15:00   Matchweek 6  Sat  Home      W   2   0  Nott'ham Forest
# 10 2023-09-30  15:00   Matchweek 7  Sat  Away      L   1   2           Wolves
# 12 2023-10-08  16:30   Matchweek 8  Sun  Away      L   0   1          Arsenal
# 13 2023-10-21  15:00   Matchweek 9  Sat  Home      W   2   1         Brighton
# 15 2023-10-29  15:30  Matchweek 10  Sun  Away      W   3   0   Manchester Utd
# 16 2023-11-04  15:00  Matchweek 11  Sat  Home      W   6   1      Bournemouth
# 18 2023-11-12  16:30  Matchweek 12  Sun  Away      D   4   4          Chelsea
# 19 2023-11-25  12:30  Matchweek 13  Sat  Home      D   1   1        Liverpool
# 21 2023-12-03  16:30  Matchweek 14  Sun  Home      D   3   3        Tottenham
# 22 2023-12-06  20:15  Matchweek 15  Wed  Away      L   0   1      Aston Villa
# 23 2023-12-10  14:00  Matchweek 16  Sun  Away      W   2   1       Luton Town
# 25 2023-12-16  15:00  Matchweek 17  Sat  Home      D   2   2   Crystal Palace
# 26 2023-12-27  20:15  Matchweek 19  Wed  Away      W   3   1          Everton
# 27 2023-12-30  15:00  Matchweek 20  Sat  Home      W   2   0    Sheffield Utd
# 29 2024-01-13  17:30  Matchweek 21  Sat  Away      W   3   2    Newcastle Utd
# 31 2024-01-31  19:30  Matchweek 22  Wed  Home      W   3   1          Burnley
# 32 2024-02-05  20:00  Matchweek 23  Mon  Away      W   3   1        Brentford
# 33 2024-02-10  12:30  Matchweek 24  Sat  Home      W   2   0          Everton
# 35 2024-02-17  17:30  Matchweek 25  Sat  Home      D   1   1          Chelsea
# 36 2024-02-20  19:30  Matchweek 18  Tue  Home      W   1   0        Brentford
# 37 2024-02-24  17:30  Matchweek 26  Sat  Away      W   1   0      Bournemouth
# 39 2024-03-03  15:30  Matchweek 27  Sun  Home      W   3   1   Manchester Utd
# 41 2024-03-10  15:45  Matchweek 28  Sun  Away      D   1   1        Liverpool
# 43 2024-03-31  16:30  Matchweek 30  Sun  Home      D   0   0          Arsenal
# 44 2024-04-03  20:15  Matchweek 31  Wed  Home      W   4   1      Aston Villa
# 45 2024-04-06  12:30  Matchweek 32  Sat  Away      W   4   2   Crystal Palace
# 47 2024-04-13  15:00  Matchweek 33  Sat  Home      W   5   1       Luton Town
# 50 2024-04-25  20:00  Matchweek 29  Thu  Away      W   4   0         Brighton
# 51 2024-04-28  16:30  Matchweek 35  Sun  Away      W   2   0  Nott'ham Forest
# 52 2024-05-04  17:30  Matchweek 36  Sat  Home      W   5   1           Wolves
# 53 2024-05-11  12:30  Matchweek 37  Sat  Away      W   4   0           Fulham
# 54 2024-05-14  20:00  Matchweek 34  Tue  Away      W   2   0        Tottenham
# 55 2024-05-19  16:00  Matchweek 38  Sun  Home      W   3   1         West Ham
#
#      xg  xga  poss  attendance          captain formation         referee  \
# 8   1.3  1.0  57.0     53413.0      Kyle Walker   4-2-3-1  Anthony Taylor
# 10  0.9  0.4  68.0     31415.0      Kyle Walker   4-2-3-1    Craig Pawson
# 12  0.5  0.4  51.0     60233.0      Kyle Walker     4-3-3  Michael Oliver
# 13  0.8  0.8  55.0     53466.0      Kyle Walker   3-2-4-1    Robert Jones
# 15  4.0  0.9  60.0     73502.0      Kyle Walker   4-2-3-1    Paul Tierney
# 16  1.9  0.9  65.0     53358.0      Kyle Walker     3-4-3    Craig Pawson
# 18  2.9  2.9  55.0     39532.0      Kyle Walker   3-2-4-1  Anthony Taylor
# 19  1.3  0.6  59.0     53289.0      Kyle Walker   3-2-4-1  Chris Kavanagh
# 21  2.6  0.5  55.0     53473.0      Kyle Walker   3-2-4-1    Simon Hooper
# 22  0.6  2.3  54.0     41421.0      Kyle Walker   3-2-4-1     John Brooks
# 23  1.6  0.3  65.0     11047.0      Kyle Walker   4-2-3-1    Tim Robinson
# 25  1.6  1.8  74.0     53248.0      Kyle Walker   4-2-3-1    Paul Tierney
# 26  2.4  1.0  72.0     39327.0      Kyle Walker   4-2-3-1     John Brooks
# 27  2.2  0.3  80.0     53108.0      Kyle Walker   4-2-3-1     David Coote
# 29  3.0  1.3  72.0     52190.0      Kyle Walker   4-2-3-1  Chris Kavanagh
# 31  1.7  1.4  74.0     52143.0  Kevin De Bruyne   4-2-3-1  Samuel Barrott
# 32  2.1  1.0  72.0     17096.0      Kyle Walker   4-1-4-1  Jarred Gillett
# 33  1.6  0.3  72.0     52187.0       Rúben Dias   4-1-4-1     John Brooks
# 35  2.6  1.4  70.0     52178.0      Kyle Walker   4-1-4-1     Andy Madley
# 36  2.3  0.4  70.0     52247.0      Kyle Walker   4-2-3-1  Darren England
# 37  1.6  0.9  62.0     11184.0       Rúben Dias   3-2-4-1  Jarred Gillett
# 39  3.3  0.2  73.0     53514.0      Kyle Walker   3-2-4-1     Andy Madley
# 41  1.6  2.7  47.0     59947.0      Kyle Walker   3-2-4-1  Michael Oliver
# 43  1.0  0.7  72.0     52178.0  Kevin De Bruyne   4-1-4-1  Anthony Taylor
# 44  3.4  0.8  67.0     53422.0       Rúben Dias   4-2-3-1  Darren England
# 45  1.9  1.1  75.0     25132.0  Kevin De Bruyne   3-2-4-1    Paul Tierney
# 47  4.2  0.5  73.0     52149.0  Kevin De Bruyne   4-2-3-1     John Brooks
# 50  1.4  0.6  64.0     31596.0      Kyle Walker   4-1-4-1  Jarred Gillett
# 51  0.9  1.9  66.0     29677.0      Kyle Walker   4-1-4-1    Simon Hooper
# 52  3.7  0.3  58.0     52439.0      Kyle Walker   4-2-3-1    Craig Pawson
# 53  3.2  0.1  64.0     24418.0  Kevin De Bruyne   4-2-3-1  Anthony Taylor
# 54  2.4  1.7  47.0     61065.0      Kyle Walker   4-2-3-1  Chris Kavanagh
# 55  1.9  0.4  71.0     55097.0      Kyle Walker   4-1-4-1     John Brooks
#
#       sh   sot  dist   fk  pk  pkatt  season            team  venue_code  \
# 8    7.0   4.0  17.2  2.0   0      0    2024  ManchesterCity           1
# 10  23.0   8.0  19.3  1.0   0      0    2024  ManchesterCity           0
# 12   4.0   0.0  14.9  0.0   0      0    2024  ManchesterCity           0
# 13  10.0   5.0  18.8  1.0   0      0    2024  ManchesterCity           1
# 15  20.0   9.0  17.2  2.0   1      1    2024  ManchesterCity           0
# 16  21.0   8.0  16.4  0.0   0      0    2024  ManchesterCity           1
# 18  14.0   9.0  16.6  1.0   1      1    2024  ManchesterCity           0
# 19  16.0   5.0  16.3  1.0   0      0    2024  ManchesterCity           1
# 21  17.0   4.0  13.4  0.0   0      0    2024  ManchesterCity           1
# 22   2.0   2.0   7.4  0.0   0      0    2024  ManchesterCity           0
# 23  18.0   6.0  18.7  1.0   0      0    2024  ManchesterCity           0
# 25  19.0   9.0  18.2  0.0   0      0    2024  ManchesterCity           1
# 26  22.0   8.0  19.5  1.0   1      1    2024  ManchesterCity           0
# 27  18.0   4.0  17.4  0.0   0      0    2024  ManchesterCity           1
# 29  27.0  11.0  19.3  2.0   0      0    2024  ManchesterCity           0
# 31  14.0   4.0  15.8  1.0   0      0    2024  ManchesterCity           1
# 32  25.0  15.0  19.2  0.0   0      0    2024  ManchesterCity           0
# 33  19.0   3.0  17.4  0.0   0      0    2024  ManchesterCity           1
# 35  31.0   5.0  15.9  1.0   0      0    2024  ManchesterCity           1
# 36  25.0  10.0  17.6  0.0   0      0    2024  ManchesterCity           1
# 37  15.0   6.0  15.5  1.0   0      0    2024  ManchesterCity           0
# 39  27.0   8.0  17.7  1.0   0      0    2024  ManchesterCity           1
# 41  10.0   6.0  18.6  0.0   0      0    2024  ManchesterCity           0
# 43  12.0   1.0  14.2  0.0   0      0    2024  ManchesterCity           1
# 44  25.0  11.0  15.9  2.0   0      0    2024  ManchesterCity           1
# 45  18.0   8.0  16.1  0.0   0      0    2024  ManchesterCity           0
# 47  36.0  12.0  16.9  0.0   1      1    2024  ManchesterCity           1
# 50  14.0   6.0  17.0  1.0   0      0    2024  ManchesterCity           0
# 51  11.0   5.0  18.7  1.0   0      0    2024  ManchesterCity           0
# 52  18.0  10.0  15.3  0.0   2      2    2024  ManchesterCity           1
# 53  15.0   8.0  17.6  0.0   1      1    2024  ManchesterCity           0
# 54   7.0   4.0  14.5  0.0   1      1    2024  ManchesterCity           0
# 55  28.0  12.0  17.9  2.0   0      0    2024  ManchesterCity           1
#
#     opp_code  hour  day_code  target  gf_rolling  ga_rolling  xg_rolling  \
# 8         15    15         5       1         2.8         0.6        2.44
# 10        19    15         5       0         2.6         0.6        2.32
# 12         0    16         6       0         2.6         1.0        2.30
# 13         4    15         5       1         2.2         1.0        1.70
# 15        13    15         6       1         1.6         1.0        1.42
# 16         2    15         5       1         1.6         0.8        1.50
# 18         6    16         6       0         2.4         1.0        1.62
# 19        10    12         5       0         3.0         1.4        2.02
# 21        17    16         6       0         3.2         1.4        2.18
# 22         1    20         2       0         3.4         1.8        2.54
# 23        11    14         6       1         2.8         2.0        1.86
# 25         7    15         5       0         2.0         2.0        1.80
# 26         8    20         2       1         1.6         1.6        1.54
# 27        16    15         5       1         2.0         1.6        1.76
# 29        14    17         5       1         1.8         1.0        1.68
# 31         5    19         2       1         2.4         1.2        2.16
# 32         3    20         0       1         2.6         1.2        2.18
# 33         8    12         5       1         2.8         1.0        2.28
# 35         6    17         5       0         2.6         0.8        2.12
# 36         3    19         1       1         2.4         1.0        2.20
# 37         2    17         5       1         2.0         0.6        2.06
# 39        13    15         6       1         1.6         0.4        2.04
# 41        10    15         6       0         1.6         0.4        2.28
# 43         0    16         6       0         1.4         0.6        2.28
# 44         1    20         2       1         1.2         0.4        1.96
# 45         7    12         5       1         1.8         0.6        2.18
# 47        11    15         5       1         2.4         1.0        2.24
# 50         4    20         3       1         2.8         1.0        2.42
# 51        15    16         6       1         3.4         0.8        2.38
# 52        19    17         5       1         3.8         0.8        2.36
# 53         9    12         5       1         4.0         0.8        2.42
# 54        17    20         1       1         4.0         0.4        2.68
# 55        18    16         6       1         3.4         0.2        2.32
#
#     xga_rolling  poss_rolling  sh_rolling  sot_rolling  dist_rolling  \
# 8          0.72          67.8        19.0          7.6         16.06
# 10         0.86          66.2        17.0          6.8         16.72
# 12         0.88          68.0        18.8          7.6         17.00
# 13         0.82          62.4        13.8          5.8         16.52
# 15         0.70          59.8        14.6          6.0         17.32
# 16         0.70          58.2        12.8          5.2         17.48
# 18         0.68          59.8        15.6          6.0         17.32
# 19         1.18          57.2        13.8          6.2         16.78
# 21         1.22          58.8        16.2          7.2         17.06
# 22         1.16          58.8        17.6          7.0         15.98
# 23         1.44          57.6        14.0          5.6         14.02
# 25         1.32          57.6        13.4          5.2         14.48
# 26         1.10          61.4        14.4          5.2         14.80
# 27         1.18          64.0        15.6          5.8         15.44
# 29         1.14          69.0        15.8          5.8         16.24
# 31         0.94          72.6        20.8          7.6         18.62
# 32         1.16          74.4        20.0          7.2         18.04
# 33         1.00          74.0        21.2          8.4         18.24
# 35         0.86          74.0        20.6          7.4         17.82
# 36         1.08          72.0        23.2          7.6         17.52
# 37         0.90          71.6        22.8          7.4         17.18
# 39         0.80          69.2        23.0          7.8         17.12
# 41         0.64          69.4        23.4          6.4         16.82
# 43         1.12          64.4        21.6          7.0         17.06
# 44         0.98          64.8        17.8          6.2         16.72
# 45         1.06          64.2        17.8          6.4         16.38
# 47         1.10          66.8        18.4          6.8         16.50
# 50         1.16          66.8        20.2          7.6         16.34
# 51         0.74          70.2        21.0          7.6         16.02
# 52         0.98          69.0        20.8          8.4         16.92
# 53         0.88          67.2        19.4          8.2         16.80
# 54         0.68          65.0        18.8          8.2         17.10
# 55         0.92          59.8        13.0          6.6         16.62
#
#     fk_rolling  pk_rolling  pkatt_rolling
# 8          0.6         0.2            0.4
# 10         1.0         0.2            0.4
# 12         1.2         0.2            0.4
# 13         0.8         0.2            0.2
# 15         1.0         0.0            0.0
# 16         1.2         0.2            0.2
# 18         0.8         0.2            0.2
# 19         0.8         0.4            0.4
# 21         1.0         0.4            0.4
# 22         0.8         0.4            0.4
# 23         0.4         0.2            0.2
# 25         0.6         0.2            0.2
# 26         0.4         0.0            0.0
# 27         0.4         0.2            0.2
# 29         0.4         0.2            0.2
# 31         0.8         0.2            0.2
# 32         0.8         0.2            0.2
# 33         0.8         0.2            0.2
# 35         0.6         0.0            0.0
# 36         0.8         0.0            0.0
# 37         0.4         0.0            0.0
# 39         0.4         0.0            0.0
# 41         0.6         0.0            0.0
# 43         0.6         0.0            0.0
# 44         0.4         0.0            0.0
# 45         0.8         0.0            0.0
# 47         0.6         0.0            0.0
# 50         0.4         0.2            0.2
# 51         0.6         0.2            0.2
# 52         0.8         0.2            0.2
# 53         0.4         0.6            0.6
# 54         0.4         0.8            0.8
# 55         0.4         0.8            0.8

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling = matches_rolling.droplevel("team")
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling.head(5)
# Out:
# /tmp/ipykernel_569500/3535975422.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
#         date   time         round  day venue result  gf  ga         opponent  \
# 0 2023-09-24  14:00   Matchweek 6  Sun  Home      D   2   2        Tottenham
# 1 2023-09-30  15:00   Matchweek 7  Sat  Away      W   4   0      Bournemouth
# 2 2023-10-08  16:30   Matchweek 8  Sun  Home      W   1   0  Manchester City
# 3 2023-10-21  17:30   Matchweek 9  Sat  Away      D   2   2          Chelsea
# 4 2023-10-28  15:00  Matchweek 10  Sat  Home      W   5   0    Sheffield Utd
#
#     xg  xga  poss  attendance          captain formation            referee  \
# 0  1.8  1.4  47.0     60156.0  Martin Ødegaard     4-3-3       Robert Jones
# 1  3.4  0.6  57.0     11193.0  Martin Ødegaard     4-3-3  Michael Salisbury
# 2  0.4  0.5  49.0     60233.0  Martin Ødegaard     4-3-3     Michael Oliver
# 3  1.0  1.3  56.0     39723.0  Martin Ødegaard     4-3-3     Chris Kavanagh
# 4  2.8  0.0  67.0     60153.0      Bukayo Saka     4-3-3       Tim Robinson
#
#      sh  sot  dist   fk  pk  pkatt  season     team  venue_code  opp_code  \
# 0  12.0  4.0  16.9  0.0   1      1    2024  Arsenal           1        17
# 1  13.0  6.0  15.5  0.0   2      2    2024  Arsenal           0         2
# 2  12.0  2.0  19.2  0.0   0      0    2024  Arsenal           1        12
# 3  13.0  3.0  14.3  0.0   0      0    2024  Arsenal           0         6
# 4  12.0  6.0  17.0  0.0   1      1    2024  Arsenal           1        16
#
#    hour  day_code  target  gf_rolling  ga_rolling  xg_rolling  xga_rolling  \
# 0    14         6       0         1.8         0.8        1.86         0.80
# 1    15         5       1         1.8         1.0        2.06         0.84
# 2    16         6       1         2.4         1.0        2.34         0.76
# 3    17         5       0         2.2         0.6        1.78         0.74
# 4    15         5       1         2.0         0.8        1.52         0.82
#
#    poss_rolling  sh_rolling  sot_rolling  dist_rolling  fk_rolling  \
# 0          66.2        15.2          5.4         16.34         0.0
# 1          60.0        14.6          4.8         15.90         0.0
# 2          60.8        14.6          5.6         15.72         0.0
# 3          56.4        13.4          4.2         16.80         0.0
# 4          56.6        12.6          3.8         16.66         0.0
#
#    pk_rolling  pkatt_rolling
# 0         0.4            0.4
# 1         0.6            0.6
# 2         0.8            0.8
# 3         0.6            0.6
# 4         0.6            0.6

# %% [markdown]
# defining function to perform machine learning model

# %%
def make_prediction(data, predictors):
    date = "2023-12-30"
    # date = "2023-11-30"
    train = data[data["date"] <= date]
    test = data[data["date"] > date]
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predictions=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_prediction(matches, predictors)
precision
# Out:
# 0.47619047619047616

# %% [markdown]
# Team names in "opponent" and "team" columns are slightly different. Defining a dictionary to handle this when merging

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key
map_values = {
    "ManchesterCity": "Manchester City",
    "ManchesterUnited": "Manchester Utd",
    "WestHamUnited": "West Ham",
    "NewcastleUnited": "Newcastle Utd",
    "TottenhamHotspur": "Tottenham",
    "AstonVilla": "Aston Villa",
    "BrightonandHoveAlbion": "Brighton",
    "LutonTown": "Luton Town",
    "WolverhamptonWanderers": "Wolves",
    "CrystalPalace": "Crystal Palace",
    "NottinghamForest": "Nott'ham Forest",
    "SheffieldUnited": "Sheffield Utd"

 
}
mapping = MissingDict(**map_values)

# %%
mapping["NottinghamForest"]
# Out:
# "Nott'ham Forest"

# %% [markdown]
# retrying model with new rolling average columns

# %%
combined, precision = make_prediction(matches_rolling, predictors+new_cols )
print(precision)
# Out:
# 0.48

# %%
(0.48 - 0.47619047619047616) * 100
# Out:
# 0.3809523809523818

# %% [markdown]
# taking rolling averages into account on the same dataset has improved the model by 0.38%

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined["new_team"] = combined["team"].map(mapping)
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])
merged[(merged["predictions_x"] == 1) & (merged["predictions_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    53
# 0    44
# Name: count, dtype: int64

# %% [markdown]
# next I'll try importing more historic match data to train my model with

# %%
new_df = pd.read_csv("2020-23_matches.csv", index_col=0)
new_df.head(5)
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           opponent   xg  xga  poss  attendance          captain formation  \
# 1         West Ham  2.2  0.5  75.0     62443.0   İlkay Gündoğan     4-3-3
# 2      Bournemouth  1.7  0.1  67.0     53453.0   İlkay Gündoğan   4-2-3-1
# 3    Newcastle Utd  2.1  1.8  69.0     52258.0   İlkay Gündoğan     4-3-3
# 4   Crystal Palace  2.2  0.1  74.0     53112.0  Kevin De Bruyne   4-2-3-1
# 5  Nott'ham Forest  3.3  0.7  74.0     53409.0   İlkay Gündoğan   4-2-3-1
#
#           referee  match report  notes    sh   sot  dist   fk   pk  pkatt  \
# 1  Michael Oliver  Match Report    NaN  13.0   1.0  18.7  1.0  1.0    1.0
# 2     David Coote  Match Report    NaN  19.0   7.0  17.5  0.0  0.0    0.0
# 3  Jarred Gillett  Match Report    NaN  21.0  10.0  16.2  1.0  0.0    0.0
# 4  Darren England  Match Report    NaN  18.0   5.0  14.1  0.0  0.0    0.0
# 5    Paul Tierney  Match Report    NaN  17.0   9.0  14.8  0.0  0.0    0.0
#
#    season             team
# 1    2023  Manchester City
# 2    2023  Manchester City
# 3    2023  Manchester City
# 4    2023  Manchester City
# 5    2023  Manchester City

# %% [markdown]
# exploring the data

# %%
len(new_df)/380/2
# Out:
# 3.0

# %%
new_df["season"].unique()
# Out:
# array([2023, 2022, 2021])

# %%
new_df.groupby("team").size().reset_index(name="count").sort_values("count", ascending=0)
# Out:
#                         team  count
# 0                    Arsenal    114
# 1                Aston Villa    114
# 4   Brighton and Hove Albion    114
# 7             Crystal Palace    114
# 6                    Chelsea    114
# 8                    Everton    114
# 12                 Liverpool    114
# 11            Leicester City    114
# 10              Leeds United    114
# 23           West Ham United    114
# 24   Wolverhampton Wanderers    114
# 19               Southampton    114
# 13           Manchester City    114
# 15          Newcastle United    114
# 14         Manchester United    114
# 20         Tottenham Hotspur    114
# 3                  Brentford     76
# 9                     Fulham     76
# 5                    Burnley     76
# 2                Bournemouth     38
# 16              Norwich City     38
# 17         Nottingham Forest     38
# 18          Sheffield United     38
# 22      West Bromwich Albion     38
# 21                   Watford     38

# %% [markdown]
# cleaning the dataframe

# %%
new_df.drop(columns=drop_cols)
new_df["date"] = pd.to_datetime(new_df["date"])
new_df["venue_code"] = new_df["venue"].astype("category").cat.codes
new_df["opp_code"] = new_df["opponent"].astype("category").cat.codes
new_df["hour"] = new_df["time"].str.replace(":.+", "", regex=True).astype("int")
new_df["day_code"] = new_df["date"].dt.day_of_week
new_df["target"] = (new_df["result"] == "W").astype("int")

# %%
new_df.sort_values("date")
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 0  2020-09-12  20:00  Premier League   Matchweek 1  Sat  Home      L   0   2
# 1  2020-09-12  12:30  Premier League   Matchweek 1  Sat  Away      W   3   0
# 0  2020-09-12  17:30  Premier League   Matchweek 1  Sat  Away      L   3   4
# 0  2020-09-12  15:00  Premier League   Matchweek 1  Sat  Home      W   1   0
# 1  2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W   4   3
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 48 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Home      W   5   0
# 40 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Home      W   1   0
# 43 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   5
# 55 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   1   2
# 51 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      D   4   4
#
#            opponent   xg  xga  poss  attendance                    captain  \
# 0     Newcastle Utd  1.0  1.6  58.0         NaN                 Mark Noble
# 1            Fulham  1.9  0.1  54.0         NaN  Pierre-Emerick Aubameyang
# 0         Liverpool  0.3  2.7  51.0         NaN                Luke Ayling
# 0       Southampton  1.1  0.9  31.0         NaN                 Scott Dann
# 1      Leeds United  2.7  0.3  49.0         NaN           Jordan Henderson
# ..              ...  ...  ...   ...         ...                        ...
# 48           Wolves  2.8  0.5  51.0     60095.0            Martin Ødegaard
# 40  Manchester City  1.3  1.6  35.0     17120.0                 David Raya
# 43          Arsenal  0.5  2.8  49.0     60095.0                 Max Kilman
# 55   Leicester City  1.4  1.4  52.0     32183.0                Declan Rice
# 51      Southampton  4.0  1.8  69.0     31129.0               James Milner
#
#    formation         referee  match report  notes    sh  sot  dist   fk   pk  \
# 0    4-2-3-1  Stuart Attwell  Match Report    NaN  15.0  3.0  16.5  0.0  0.0
# 1      3-4-3  Chris Kavanagh  Match Report    NaN  13.0  5.0  14.1  2.0  0.0
# 0    4-1-4-1  Michael Oliver  Match Report    NaN   6.0  3.0  19.9  1.0  0.0
# 0      4-4-2   Jonathan Moss  Match Report    NaN   5.0  3.0  10.6  0.0  0.0
# 1      4-3-3  Michael Oliver  Match Report    NaN  20.0  4.0  18.4  0.0  2.0
# ..       ...             ...           ...    ...   ...  ...   ...  ...  ...
# 48     4-3-3  Andre Marriner  Match Report    NaN  14.0  8.0  13.7  1.0  0.0
# 40     5-3-2     John Brooks  Match Report    NaN  11.0  4.0  14.0  0.0  0.0
# 43     4-3-3  Andre Marriner  Match Report    NaN   6.0  0.0  14.7  1.0  0.0
# 55   4-2-3-1    Simon Hooper  Match Report    NaN  16.0  3.0  16.7  0.0  0.0
# 51     4-3-3  Darren England  Match Report    NaN  30.0  8.0  18.5  0.0  0.0
#
#     pkatt  season                     team  venue_code  opp_code  hour  \
# 0     0.0    2021          West Ham United           1        15    20
# 1     0.0    2021                  Arsenal           0         9    12
# 0     0.0    2021             Leeds United           0        12    17
# 0     0.0    2021           Crystal Palace           1        19    15
# 1     2.0    2021                Liverpool           1        10    17
# ..    ...     ...                      ...         ...       ...   ...
# 48    0.0    2023                  Arsenal           1        24    16
# 40    0.0    2023                Brentford           1        13    16
# 43    0.0    2023  Wolverhampton Wanderers           0         0    16
# 55    0.0    2023          West Ham United           0        11    16
# 51    0.0    2023                Liverpool           0        19    16
#
#     day_code  target
# 0          5       0
# 1          5       1
# 0          5       0
# 0          5       1
# 1          5       1
# ..       ...     ...
# 48         6       1
# 40         6       1
# 43         6       0
# 55         6       0
# 51         6       0
#
# [2280 rows x 32 columns]

# %% [markdown]
# here I split the 2020-2023 data set into roughly 80-20 split using the date "2022-12-26" to split the data.

# %%
def make_prediction(data, predictors):
    date = "2022-12-26"
    # date = "2023-11-30"
    train = data[data["date"] <= date]
    test = data[data["date"] > date]
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predictions=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %% [markdown]
# prediction using 21-23 match data without rolling averages

# %%
combined, precision = make_prediction(new_df, predictors)
precision
# Out:
# 0.46226415094339623

# %%
matches_rolling_21_23 = new_df.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling_21_23 = matches_rolling_21_23.droplevel("team")
matches_rolling_21_23.index = range(matches_rolling_21_23.shape[0])
# Out:
# /tmp/ipykernel_569500/2989878719.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling_21_23 = new_df.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %% [markdown]
# prediction using 21-23 match data with rolling averages

# %%
combined, precision = make_prediction(matches_rolling_21_23, predictors + new_cols)
precision
# Out:
# 0.5045045045045045

# %% [markdown]
# now I'll try using the entirety of 20-23 (3 seasons) to predict the outcomes of the 2023-2024 season

# %%
train = matches_rolling_21_23
test = matches_rolling
rf.fit(train[predictors + new_cols], train["target"])
preds = rf.predict(test[predictors + new_cols])
combined = pd.DataFrame(dict(actual=test["target"], predictions=preds), index=test.index)
precision = precision_score(test["target"], preds)
precision
# Out:
# 0.6293706293706294

# %% [markdown]
# This model has netted my highest precision score of 63%. As expected a larger training set generally improves your model in combination with a high quality features

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined["new_team"] = combined["team"].map(mapping)
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])
merged[(merged["predictions_x"] == 1) & (merged["predictions_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    79
# 0    36
# Name: count, dtype: int64
